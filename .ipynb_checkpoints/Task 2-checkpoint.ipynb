# %% [markdown]
# # Task 2
# Import the Luxury Loan Portfolio into pandas dataframes and use ​Plotly dash​ to create a web app that displays 3 charts of different types that show interesting business metrics.

# %% [markdown]
# # Importing Libraries

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default='notebook'

import pandas as pd

# %% [markdown]
# # Importing Data

# %%
df_raw = pd.read_csv('/Users/giovannorachmat/Git (Personal)/dkatalis-take-home-test-bi-analyst/datasets/luxury_loan_portfolio.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   loan_id                           1678 non-null   object
#  1   funded_amount                     1678 non-null   float64
#  2   funded_date                       1678 non-null   object
#  3   duration years                    1678 non-null   int64
#  4   duration months                   1678 non-null   int64
#  5   10 yr treasury index date funded  1678 non-null   float64
#  6   interest rate percent             1678 non-null   float64
#  7   interest rate                     1678 non-null   float64
#  8   payments                          1678 non-null   float64
#  9   total past payments               1678 non-null   int64
#  10  loan balance                      1678 non-null   float64
#  11  property value                    1678 non-null   float64
#  12  purpose                           1678 non-null   object
#  13  firstname                         1678 non-null   object
#  14  middlename                        1678 non-null   object
#  15  lastname                          1678 non-null   object
#  16  social                            1678 non-null   object
#  17  phone                             1678 non-null   object
#  18  title                             1666 non-null   object
#  19  employment length                 1678 non-null   int64
#  20  BUILDING CLASS CATEGORY           1678 non-null   object
#  21  TAX CLASS AT PRESENT              1678 non-null   object
#  22  BUILDING CLASS AT PRESENT         1678 non-null   object
#  23  ADDRESS 1                         1678 non-null   object
#  24  ADDRESS 2                         1678 non-null   object
#  25  ZIP CODE                          1678 non-null   int64
#  26  CITY                              1678 non-null   object
#  27  STATE                             1678 non-null   object
#  28  TOTAL UNITS                       1678 non-null   int64
#  29  LAND SQUARE FEET                  1678 non-null   object
#  30  GROSS SQUARE FEET                 1678 non-null   object
#  31  TAX CLASS AT TIME OF SALE         1678 non-null   int64
# dtypes: float64(7), int64(7), object(18)
# memory usage: 419.6+ KB

# %%
df_raw.columns
# Out:
# Index(['loan_id', 'funded_amount', 'funded_date', 'duration years',
#        'duration months', '10 yr treasury index date funded',
#        'interest rate percent', 'interest rate', 'payments',
#        'total past payments', 'loan balance', 'property value', 'purpose',
#        'firstname', 'middlename', 'lastname', 'social', 'phone', 'title',
#        'employment length', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS 1', 'ADDRESS 2', 'ZIP CODE',
#        'CITY', 'STATE', 'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
#        'TAX CLASS AT TIME OF SALE'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
# Removing unnecessary columns
df_parse = df_raw.drop(columns=[
    '10 yr treasury index date funded',
    'firstname',
    'middlename',
    'lastname',
    'social',
    'phone',
    'ADDRESS 1',
    'ADDRESS 2',
    'ZIP CODE',
    'TOTAL UNITS',
    'LAND SQUARE FEET',
    'GROSS SQUARE FEET',
    'TAX CLASS AT TIME OF SALE',
    'BUILDING CLASS CATEGORY'
])

# %%
df_parse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    1678 non-null   object
#  1   funded_amount              1678 non-null   float64
#  2   funded_date                1678 non-null   object
#  3   duration years             1678 non-null   int64
#  4   duration months            1678 non-null   int64
#  5   interest rate percent      1678 non-null   float64
#  6   interest rate              1678 non-null   float64
#  7   payments                   1678 non-null   float64
#  8   total past payments        1678 non-null   int64
#  9   loan balance               1678 non-null   float64
#  10  property value             1678 non-null   float64
#  11  purpose                    1678 non-null   object
#  12  title                      1666 non-null   object
#  13  employment length          1678 non-null   int64
#  14  TAX CLASS AT PRESENT       1678 non-null   object
#  15  BUILDING CLASS AT PRESENT  1678 non-null   object
#  16  CITY                       1678 non-null   object
#  17  STATE                      1678 non-null   object
# dtypes: float64(6), int64(4), object(8)
# memory usage: 236.1+ KB

# %%
df_parse.head()
# Out:
#      loan_id  funded_amount funded_date  duration years  duration months  \
# 0  LL0000076       790000.0  2012-04-27              20              240
# 1  LL0000151      1720000.0  2014-10-14              15              180
# 2  LL0000161      3720000.0  2014-06-07              15              180
# 3  LL0000175      1079000.0  2012-02-23              20              240
# 4  LL0000178      2028000.0  2016-04-01              20              240
#
#    interest rate percent  interest rate  payments  total past payments  \
# 0                  3.359        0.03359   4524.65                   92
# 1                  3.508        0.03508  12302.74                   62
# 2                  3.896        0.03896  27322.92                   66
# 3                  3.389        0.03389   6196.40                   94
# 4                  3.188        0.03188  11439.05                   45
#
#    loan balance  property value purpose                                 title  \
# 0     373732.18        930250.0    boat  Vice President Global Field Services
# 1     957230.24       1995250.0    boat               Senior program manager
# 2    1916687.35       3881700.0    boat                                   NaN
# 3     496538.75       1402450.0    boat                         Vice presiden
# 4    1513242.57       2216500.0    boat                        Bank examiner
#
#    employment length TAX CLASS AT PRESENT BUILDING CLASS AT PRESENT  \
# 0                  6                   2C                        R1
# 1                 10                   1A                        R3
# 2                  1                   1A                        R3
# 3                 17                   2C                        R1
# 4                  5                    4                        RW
#
#             CITY STATE
# 0  New York City    NY
# 1  New York City    NY
# 2  New York City    NY
# 3  New York City    NY
# 4  New York City    NY

# %%
df_parse.columns
# Out:
# Index(['loan_id', 'funded_amount', 'funded_date', 'duration years',
#        'duration months', 'interest rate percent', 'interest rate', 'payments',
#        'total past payments', 'loan balance', 'property value', 'purpose',
#        'title', 'employment length', 'TAX CLASS AT PRESENT',
#        'BUILDING CLASS AT PRESENT', 'CITY', 'STATE'],
#       dtype='object')

# %%
# Renaming columns for standardization
df_pure = df_parse.rename(columns={
    'TAX CLASS AT PRESENT':'tax_class',
    'BUILDING CLASS AT PRESENT':'building_class_at_present',
    'CITY':'city',
    'STATE':'state',
    'payments':'payment_amount',
    'purpose':'asset_type',
    'duration years':'duration_years',
    'duration months':'duration_months',
    'interest rate percent':'interest_rate_percent',
    'interest rate':'interest_rate',
    'total past payments':'total_past_payments',
    'loan balance':'loan_balance',
    'property value':'property_value',
    'employment length':'employment_length'
})

# %%
df_pure.head()
# Out:
#      loan_id  funded_amount funded_date  duration_years  duration_months  \
# 0  LL0000076       790000.0  2012-04-27              20              240
# 1  LL0000151      1720000.0  2014-10-14              15              180
# 2  LL0000161      3720000.0  2014-06-07              15              180
# 3  LL0000175      1079000.0  2012-02-23              20              240
# 4  LL0000178      2028000.0  2016-04-01              20              240
#
#    interest_rate_percent  interest_rate  payment_amount  total_past_payments  \
# 0                  3.359        0.03359         4524.65                   92
# 1                  3.508        0.03508        12302.74                   62
# 2                  3.896        0.03896        27322.92                   66
# 3                  3.389        0.03389         6196.40                   94
# 4                  3.188        0.03188        11439.05                   45
#
#    loan_balance  property_value asset_type  \
# 0     373732.18        930250.0       boat
# 1     957230.24       1995250.0       boat
# 2    1916687.35       3881700.0       boat
# 3     496538.75       1402450.0       boat
# 4    1513242.57       2216500.0       boat
#
#                                   title  employment_length tax_class  \
# 0  Vice President Global Field Services                  6        2C
# 1               Senior program manager                  10        1A
# 2                                   NaN                  1        1A
# 3                         Vice presiden                 17        2C
# 4                        Bank examiner                   5         4
#
#   building_class_at_present           city state
# 0                        R1  New York City    NY
# 1                        R3  New York City    NY
# 2                        R3  New York City    NY
# 3                        R1  New York City    NY
# 4                        RW  New York City    NY

# %%
df_pure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    1678 non-null   object
#  1   funded_amount              1678 non-null   float64
#  2   funded_date                1678 non-null   object
#  3   duration_years             1678 non-null   int64
#  4   duration_months            1678 non-null   int64
#  5   interest_rate_percent      1678 non-null   float64
#  6   interest_rate              1678 non-null   float64
#  7   payment_amount             1678 non-null   float64
#  8   total_past_payments        1678 non-null   int64
#  9   loan_balance               1678 non-null   float64
#  10  property_value             1678 non-null   float64
#  11  asset_type                 1678 non-null   object
#  12  title                      1666 non-null   object
#  13  employment_length          1678 non-null   int64
#  14  tax_class                  1678 non-null   object
#  15  building_class_at_present  1678 non-null   object
#  16  city                       1678 non-null   object
#  17  state                      1678 non-null   object
# dtypes: float64(6), int64(4), object(8)
# memory usage: 236.1+ KB

# %%
df_pure['asset_type']=df_pure['asset_type'].astype('category')
df_pure['tax_class']=df_pure['tax_class'].astype('category')
df_pure['building_class_at_present']=df_pure['building_class_at_present'].astype('category')
df_pure['city']=df_pure['city'].astype('category')
df_pure['state']=df_pure['state'].astype('category')
df_pure['funded_date']=df_pure['funded_date'].astype('datetime64[ns]')

# %%
df_pure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    1678 non-null   object
#  1   funded_amount              1678 non-null   float64
#  2   funded_date                1678 non-null   datetime64[ns]
#  3   duration_years             1678 non-null   int64
#  4   duration_months            1678 non-null   int64
#  5   interest_rate_percent      1678 non-null   float64
#  6   interest_rate              1678 non-null   float64
#  7   payment_amount             1678 non-null   float64
#  8   total_past_payments        1678 non-null   int64
#  9   loan_balance               1678 non-null   float64
#  10  property_value             1678 non-null   float64
#  11  asset_type                 1678 non-null   category
#  12  title                      1666 non-null   object
#  13  employment_length          1678 non-null   int64
#  14  tax_class                  1678 non-null   category
#  15  building_class_at_present  1678 non-null   category
#  16  city                       1678 non-null   category
#  17  state                      1678 non-null   category
# dtypes: category(5), datetime64[ns](1), float64(6), int64(4), object(2)
# memory usage: 181.1+ KB

# %%
df_pure.head()
# Out:
#      loan_id  funded_amount funded_date  duration_years  duration_months  \
# 0  LL0000076       790000.0  2012-04-27              20              240
# 1  LL0000151      1720000.0  2014-10-14              15              180
# 2  LL0000161      3720000.0  2014-06-07              15              180
# 3  LL0000175      1079000.0  2012-02-23              20              240
# 4  LL0000178      2028000.0  2016-04-01              20              240
#
#    interest_rate_percent  interest_rate  payment_amount  total_past_payments  \
# 0                  3.359        0.03359         4524.65                   92
# 1                  3.508        0.03508        12302.74                   62
# 2                  3.896        0.03896        27322.92                   66
# 3                  3.389        0.03389         6196.40                   94
# 4                  3.188        0.03188        11439.05                   45
#
#    loan_balance  property_value asset_type  \
# 0     373732.18        930250.0       boat
# 1     957230.24       1995250.0       boat
# 2    1916687.35       3881700.0       boat
# 3     496538.75       1402450.0       boat
# 4    1513242.57       2216500.0       boat
#
#                                   title  employment_length tax_class  \
# 0  Vice President Global Field Services                  6        2C
# 1               Senior program manager                  10        1A
# 2                                   NaN                  1        1A
# 3                         Vice presiden                 17        2C
# 4                        Bank examiner                   5         4
#
#   building_class_at_present           city state
# 0                        R1  New York City    NY
# 1                        R3  New York City    NY
# 2                        R3  New York City    NY
# 3                        R1  New York City    NY
# 4                        RW  New York City    NY

# %% [markdown]
# # Creating Plotly Graph Objects

# %% [markdown]
# ### *Q1: To which asset does the funded loan go?*

# %%
# Get total number of funded amount per asset_type
q1_df = df_pure.groupby(['tax_class','asset_type'])[['funded_amount']].agg('sum').reset_index() # Resetting index to make the funded_amount column name unchanged

q1_df
# Out:
#    tax_class           asset_type  funded_amount
# 0          1                 boat      3672000.0
# 1          1  commerical property     30928500.0
# 2          1                 home     24499500.0
# 3          1  investment property     28869000.0
# 4          1                plane      6880000.0
# 5         1A                 boat     14466000.0
# 6         1A  commerical property     79463000.0
# 7         1A                 home     70204500.0
# 8         1A  investment property     76873500.0
# 9         1A                plane      3240000.0
# 10        1C                 boat      2018000.0
# 11        1C  commerical property     80897500.0
# 12        1C                 home     64336500.0
# 13        1C  investment property     73488000.0
# 14        1C                plane      4143000.0
# 15         2                 boat      8923500.0
# 16         2  commerical property    214399500.0
# 17         2                 home    219612500.0
# 18         2  investment property    215781000.0
# 19         2                plane     16800000.0
# 20        2A                 boat     20276500.0
# 21        2A  commerical property    107037500.0
# 22        2A                 home    131796500.0
# 23        2A  investment property    147295000.0
# 24        2A                plane     31865000.0
# 25        2B                 boat     18535000.0
# 26        2B  commerical property     61694500.0
# 27        2B                 home     58293500.0
# 28        2B  investment property     37420500.0
# 29        2B                plane       770000.0
# 30        2C                 boat     23882500.0
# 31        2C  commerical property    300843000.0
# 32        2C                 home    296756000.0
# 33        2C  investment property    307162000.0
# 34        2C                plane     13953000.0
# 35         4                 boat     13190000.0
# 36         4  commerical property     34243500.0
# 37         4                 home     50804000.0
# 38         4  investment property     51023500.0
# 39         4                plane    156000000.0

# %%
q1_px = px.bar(q1_df, x="asset_type", y="funded_amount",
 color="tax_class",
 labels={"funded_amount":"Total Funded Amount","asset_type":"Type of Asset","tax_class":"Tax Class"},
 title="Total Funded Amount per Purpose"
)

q1_px.show()
# Out:
# <div>
#
#
#             <div id="826a5ab8-559b-4009-8136-54ae95c3bcdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("826a5ab8-559b-4009-8136-54ae95c3bcdb")) {
#                     Plotly.newPlot(
#                         '826a5ab8-559b-4009-8136-54ae95c3bcdb',
#                         [{"alignmentgroup": "True", "hovertemplate": "Tax Class=1<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#636efa"}, "name": "1", "offsetgroup": "1", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [3672000.0, 30928500.0, 24499500.0, 28869000.0, 6880000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=1A<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "1A", "marker": {"color": "#EF553B"}, "name": "1A", "offsetgroup": "1A", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [14466000.0, 79463000.0, 70204500.0, 76873500.0, 3240000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=1C<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "1C", "marker": {"color": "#00cc96"}, "name": "1C", "offsetgroup": "1C", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [2018000.0, 80897500.0, 64336500.0, 73488000.0, 4143000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=2<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "2", "marker": {"color": "#ab63fa"}, "name": "2", "offsetgroup": "2", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [8923500.0, 214399500.0, 219612500.0, 215781000.0, 16800000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=2A<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "2A", "marker": {"color": "#FFA15A"}, "name": "2A", "offsetgroup": "2A", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [20276500.0, 107037500.0, 131796500.0, 147295000.0, 31865000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=2B<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "2B", "marker": {"color": "#19d3f3"}, "name": "2B", "offsetgroup": "2B", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [18535000.0, 61694500.0, 58293500.0, 37420500.0, 770000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=2C<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "2C", "marker": {"color": "#FF6692"}, "name": "2C", "offsetgroup": "2C", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [23882500.0, 300843000.0, 296756000.0, 307162000.0, 13953000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Tax Class=4<br>Type of Asset=%{x}<br>Total Funded Amount=%{y}<extra></extra>", "legendgroup": "4", "marker": {"color": "#B6E880"}, "name": "4", "offsetgroup": "4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["boat", "commerical property", "home", "investment property", "plane"], "xaxis": "x", "y": [13190000.0, 34243500.0, 50804000.0, 51023500.0, 156000000.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"title": {"text": "Tax Class"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scatterm
